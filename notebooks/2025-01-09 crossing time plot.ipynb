# %%
import glob

import scipy.stats as stats
import scipy.integrate
import numpy as np

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

# %%
import pickle
import rubinml
# Out:
# /Users/duncan/Documents/code/physics/repos/rubin_sim/rubin_sim/utils/__init__.py:6: DeprecationWarning: rubin_sim.utils is deprecated, switch to rubin_scheduler.utils
#   warnings.warn("rubin_sim.utils is deprecated, switch to rubin_scheduler.utils", DeprecationWarning)

# %%
rates_files = glob.glob('/Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/*.pickle')

# %%
rates_by_mass = {}
for rate_file in rates_files:
  print(rate_file)
  try:
    with open(rate_file, 'rb') as f:
      rates, info = pickle.load(f)
  except:
    print('failed')
    pass
  rates_by_mass[info['pbhmass']] = rubinml.rates_to_rubin_counts(rates)
# Out:
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728633317_ut-5_m-1.00e-12sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728633749_ut-5_m-1.78e-12sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728634173_ut-5_m-3.16e-12sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728634596_ut-5_m-5.62e-12sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728635020_ut-5_m-1.00e-11sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728635441_ut-5_m-1.78e-11sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728635865_ut-5_m-3.16e-11sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728636287_ut-5_m-5.62e-11sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728636701_ut-5_m-1.00e-10sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728637113_ut-5_m-1.78e-10sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728637525_ut-5_m-3.16e-10sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728637928_ut-5_m-5.62e-10sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728638324_ut-5_m-1.00e-09sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728638712_ut-5_m-1.78e-09sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728639090_ut-5_m-3.16e-09sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728639455_ut-5_m-5.62e-09sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728639807_ut-5_m-1.00e-08sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728640142_ut-5_m-1.78e-08sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728640460_ut-5_m-3.16e-08sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728640762_ut-5_m-5.62e-08sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728641047_ut-5_m-1.00e-07sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728641318_ut-5_m-1.78e-07sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728641578_ut-5_m-3.16e-07sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728641828_ut-5_m-5.62e-07sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728642069_ut-5_m-1.00e-06sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728642303_ut-5_m-1.78e-06sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728642532_ut-5_m-3.16e-06sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728642761_ut-5_m-5.62e-06sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728642989_ut-5_m-1.00e-05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728643210_ut-5_m-1.78e-05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728643429_ut-5_m-3.16e-05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728643644_ut-5_m-5.62e-05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728643868_ut-5_m-1.00e-04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728644084_ut-5_m-1.78e-04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728644308_ut-5_m-3.16e-04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728644532_ut-5_m-5.62e-04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728644751_ut-5_m-1.00e-03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728644976_ut-5_m-1.78e-03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728645194_ut-5_m-3.16e-03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728645408_ut-5_m-5.62e-03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728645623_ut-5_m-1.00e-02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728645844_ut-5_m-1.78e-02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728646069_ut-5_m-3.16e-02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728646294_ut-5_m-5.62e-02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728646519_ut-5_m-1.00e-01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728646733_ut-5_m-1.78e-01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728646947_ut-5_m-3.16e-01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728647163_ut-5_m-5.62e-01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728647380_ut-5_m-1.00e+00sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728647599_ut-5_m-1.78e+00sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728647815_ut-5_m-3.16e+00sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728648031_ut-5_m-5.62e+00sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728648243_ut-5_m-1.00e+01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728648456_ut-5_m-1.78e+01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728648669_ut-5_m-3.16e+01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728648881_ut-5_m-5.62e+01sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728649094_ut-5_m-1.00e+02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728649307_ut-5_m-1.78e+02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728649521_ut-5_m-3.16e+02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728649734_ut-5_m-5.62e+02sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728649947_ut-5_m-1.00e+03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728650158_ut-5_m-1.78e+03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728650374_ut-5_m-3.16e+03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728650592_ut-5_m-5.62e+03sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728650806_ut-5_m-1.00e+04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728651023_ut-5_m-1.78e+04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728651239_ut-5_m-3.16e+04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728651457_ut-5_m-5.62e+04sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728651675_ut-5_m-1.00e+05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728651896_ut-5_m-1.78e+05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728652114_ut-5_m-3.16e+05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728652332_ut-5_m-5.62e+05sm.pickle
# /Volumes/thesis/rubin-sim/userdata/opsim_ml/rates/10k/rates_ml_rates_1728652551_ut-5_m-1.00e+06sm.pickle

# %%
ratedf = pd.DataFrame(rates_by_mass.items(), columns=['pbhmass', 'rate'])

# %%
rate = 137208

# %%
ratedf.plot.scatter('pbhmass', 'rate')
plt.xscale('log')
plt.yscale('log')

# %%
def exclusion_from_rate(lambda_0=0,k_obs=0, confidence_level=0.95):
  if lambda_0 == 0:
    return 1
  # Compute the upper limit for the Poisson mean using the inverse CDF
  # ppf gives the value of the parameter such that the CDF is equal to the given percentile
  upper_limit_lambda = stats.poisson.ppf(confidence_level, k_obs + 1)

  # If you have a known baseline rate (lambda_0), calculate the upper limit for the modulation factor (mu)
  upper_limit_mu = upper_limit_lambda / lambda_0

  return min(upper_limit_mu,1)

# %%
exclusions = {}
for mass, rate in rates_by_mass.items():
  exclusions[mass] = exclusion_from_rate(rate)

# %%
exclusions_min = {}
for mass, rate in rates_by_mass.items():
  exclusions_min[mass] = exclusion_from_rate(rate*0.5+819236, k_obs=819236)

# %%
exclusion_df = pd.DataFrame(exclusions.items(), columns=['pbhmass', 'exclusion'])

# %%
exclusion_min_df = pd.DataFrame(exclusions_min.items(), columns=['pbhmass', 'exclusion'])

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k/detections/*baseline_v3.6_10yrs*.pickle')
ndetections = []
masses = []
opsims= []
for file in result_files_wide10k:
  with open(file, 'rb') as f:

    events_info, detections = pickle.load(f)
    
    masses.append(events_info['pbhmass'])
    opsims.append(events_info['opsim'])
    ndetections.append(np.sum(detections)/detections.shape[0])
    # print(detections)

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k/detections/*.pickle')
event_dfs = []
# ndetections = []
# masses = []
# opsims= []
for file in result_files_wide10k:
  with open(file, 'rb') as f:
    events_info, detections = pickle.load(f)
  with open(events_info['original file'], 'rb') as f:
    events_df, sim_info = pickle.load(f)
  # print(detections)
  events_df=events_df[['crossing_time','umin']]
  events_df['pbhmass'] = events_info['pbhmass']
  events_df['detected'] = (detections.filled(0)==1)
  event_dfs.append(events_df)

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k/detections/*.pickle')
crossing_time_info = {}
# ndetections = []
# masses = []
# opsims= []
for file in result_files_wide10k:
  with open(file, 'rb') as f:
    events_info, detections = pickle.load(f)
  with open(events_info['original file'], 'rb') as f:
    events_df, sim_info = pickle.load(f)
  # print(detections)
  crossing_time_info[events_info['pbhmass']] = np.percentile(events_df['crossing_time'][(detections.filled(0)==1)], (5,50,95))

# %%
result_files_wide10k
# Out:
# ['/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e+06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_1.00e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/baseline_v3.6_10yrs_3.16e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e+06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_1.00e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/four_cycle_v3.6_10yrs_3.16e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e+06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_1.00e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/no_too_v3.6_10yrs_3.16e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e+06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_1.00e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/noroll_v3.6_10yrs_3.16e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e+06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_1.00e-12sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e+00sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e+01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e+02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e+03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e+04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e+05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-01sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-02sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-03sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-04sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-05sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-06sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-07sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-08sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-09sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-10sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-11sm.pickle',
#  '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k/detections/one_snap_v3.6_10yrs_3.16e-12sm.pickle']

# %%
events_df=pd.concat(event_dfs, ignore_index=True)

# %%
events_df
# Out:
#          crossing_time      umin       pbhmass  detected
# 0           420.384557  2.915526  1.000000e+00      True
# 1           495.775397  3.018684  1.000000e+00     False
# 2          1899.507509  1.084068  1.000000e+00      True
# 3           113.289622  2.632362  1.000000e+00     False
# 4          1221.655194  4.378325  1.000000e+00     False
# ...                ...       ...           ...       ...
# 1849995       1.544834  3.552415  3.162278e-12      True
# 1849996       1.205868  4.489523  3.162278e-12     False
# 1849997       1.296524  3.805762  3.162278e-12     False
# 1849998       1.083485  3.387984  3.162278e-12     False
# 1849999       2.295130  1.215098  3.162278e-12     False
#
# [1850000 rows x 4 columns]

# %%
subdf = events_df[(events_df['pbhmass']>10**(-4)) &
                  (events_df['pbhmass']<10**(2))]
sns.displot(subdf, x='pbhmass', y='crossing_time',
            log_scale=True, cmap='gist_heat',cbar=True)
plt.ylabel(r'$t_E$ (hours)')
plt.xlabel(r'PBH Mass ($M_\odot$)')
# plt.colorbar()
plt.title('Simulated crossing times for events from \nPBH distributions of varying mass')
plt.tight_layout()
plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/rubinsim/tE-pbhmass-dist-2.pdf')

# %%
subdf = events_df[(events_df['pbhmass']>10**(-4)) &
                  (events_df['pbhmass']<10**(2)) &
                  (events_df['detected'])]
sns.displot(subdf, x='pbhmass', y='crossing_time',
            log_scale=True, cmap='gist_heat')
plt.ylabel(r'$t_E$ (hours)')
plt.xlabel(r'PBH Mass ($M_\odot$)')
plt.title('Simulated detected crossing times for events from \nPBH distributions of varying mass')
plt.tight_layout()
plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/rubinsim/tE-pbhmass-detected-dist.pdf')

# %%
events_df.memory_usage()
# Out:
# Index              132
# source_index     80000
# gall             80000
# galb             80000
# mu0              80000
# dl               80000
# umin             80000
# crossing_time    80000
# lograte          80000
# dtype: int64

# %%
masses = list(crossing_time_info.keys())
cts = [ v[1] for v in crossing_time_info.values()]
errs = np.array([ [v[0],v[2]] for v in crossing_time_info.values()]).T
plt.errorbar(masses, cts, yerr=np.abs(errs-cts), linestyle='None', marker='.')
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'PBH mass ($M_\odot$)')
plt.ylabel(r'Crossing time (hours)')
# Out:
# Text(0, 0.5, 'Crossing time (hours)')

# %%
import seaborn as sns

# %%
masses = list(crossing_time_info.keys())

cts = [ v[1] for v in crossing_time_info.values()]
errs = np.array([ [v[0],v[2]] for v in crossing_time_info.values()]).T
plt.errorbar(masses, cts, yerr=np.abs(errs-cts), linestyle='None', marker='.')
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'PBH mass ($M_\odot$)')
plt.ylabel(r'Crossing time (hours)')
# Out:
# Text(0, 0.5, 'Crossing time (hours)')

# %%
crossing_time_bounds = {k:[v[0],v[2]] for k,v in crossing_time_info.items()}

# %%
crossing_time_info
# Out:
# {1.0: array([ 231.65585092,  763.86670803, 3822.41539659]),
#  10.0: array([  690.09933214,  2215.78488614, 10602.3871556 ]),
#  100.0: array([ 1999.41308424,  6168.33844583, 27579.47916418]),
#  1000.0: array([ 5524.55553638, 16905.078058  , 70338.35152693]),
#  10000.0: array([ 16651.55388609,  49341.06173317, 142908.34885906]),
#  100000.0: array([ 40942.21537127, 109292.05247954, 167416.94438874]),
#  1000000.0: array([ 43317.32314155, 125421.28860217, 170510.81867226]),
#  0.1: array([  74.7299633 ,  267.70406142, 1549.97384444]),
#  0.01: array([ 26.93087729,  95.8740611 , 513.02627591]),
#  0.001: array([  9.91866542,  37.86317851, 205.23019304]),
#  0.0001: array([ 3.25108777, 12.48638904, 71.81206972]),
#  1e-05: array([ 1.32855293,  4.3923003 , 24.83707325]),
#  1e-06: array([ 1.13423383,  3.00661792, 57.35375511]),
#  1e-07: array([ 1.05239546,  2.59241812, 22.30618784]),
#  1e-08: array([ 1.03028863,  2.4548968 , 16.50180918]),
#  1e-09: array([ 1.06618427,  2.96164216, 23.91505505]),
#  1e-10: array([ 1.14749375,  2.98587808, 23.99879881]),
#  1e-11: array([ 1.07773767,  2.79882805, 28.25603928]),
#  1e-12: array([ 1.06728041,  3.32770707, 26.58163979]),
#  3.1622776601683795: array([ 389.44213584, 1336.23843461, 6348.61454848]),
#  31.622776601683793: array([ 1167.25180074,  3777.38039869, 17438.66318159]),
#  316.22776601683796: array([ 3225.95793962, 10138.17029445, 43711.22235407]),
#  3162.2776601683795: array([ 10306.16745583,  28800.48483302, 103614.6658149 ]),
#  31622.776601683792: array([ 28666.80991661,  77107.05356716, 158035.10536955]),
#  316227.7660168379: array([ 49822.60691766, 131523.61180481, 171664.32644064]),
#  0.31622776601683794: array([ 129.84661716,  455.57883165, 2459.73501924]),
#  0.03162277660168379: array([ 47.43664443, 163.66042708, 881.20368446]),
#  0.0031622776601683794: array([ 15.63109223,  58.44468507, 365.24574137]),
#  0.00031622776601683794: array([  5.4593044 ,  23.4532718 , 138.71488702]),
#  3.1622776601683795e-05: array([ 1.71552805,  7.46553304, 36.39691889]),
#  3.162277660168379e-06: array([ 1.15104046,  3.22866581, 25.6303908 ]),
#  3.162277660168379e-07: array([ 1.11106531,  3.06981385, 20.81258888]),
#  3.162277660168379e-08: array([ 1.03573899,  2.73997916, 30.35610045]),
#  3.1622776601683795e-09: array([ 1.11661713,  2.78580184, 14.5139219 ]),
#  3.1622776601683795e-10: array([ 1.11178719,  2.571923  , 20.99402502]),
#  3.1622776601683794e-11: array([ 1.11211481,  2.792868  , 21.08960908]),
#  3.1622776601683794e-12: array([ 1.0641266 ,  3.10563459, 31.54496721])}

# %%
errs = np.array(list(crossing_time_bounds.values())).T
exclusions_sobh_in_time_df_fisher = pd.DataFrame(exclusions_sobh_in_time_fisher,columns=['pbhmass','time (days)', 'eff','ndetections', 'exclusion'])
df_pivot = np.log10(exclusions_sobh_in_time_df_fisher.pivot(index="time (days)", columns="pbhmass", values="exclusion"))
sns.heatmap(df_pivot, fmt='.1e',cbar_kws={'label': r'log$_{10}(f_{DM})$'})
plt.errorbar(masses, cts, yerr=np.abs(errs-cts), linestyle='None', marker='.')
plt.yscale('log')
plt.xscale('log')
plt.xlabel(r'PBH mass ($M_\odot$)')
plt.ylabel(r'Crossing time (hours)')
# Out:
# Text(0, 0.5, 'Crossing time (hours)')

# %%
print(np.max(errs.flat))
print(np.min(errs.flat))
# Out:
# 171664.3264406399
# 1.0302886264138902

# %%
365*10*24*2
# Out:
# 175200

# %%
crossing_time_info[10**5]
# Out:
# array([ 40942.21537127, 109292.05247954, 167416.94438874])

# %%
def log_fraction(signal_bounds, background_bounds=(365*10*24*2,1)):
  return np.abs(np.log(np.divide(*signal_bounds)))/np.abs(np.log(np.divide(*background_bounds)))

# %%
log_fraction((1,10))
# Out:
# 0.19071107016365269

# %%
len(ndetections)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 len(ndetections)
#
# NameError: name 'ndetections' is not defined

# %%
len(masses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 len(masses)
#
# NameError: name 'masses' is not defined

# %%
det_df = pd.DataFrame({'eff':np.array(ndetections),
                       'pbhmass' : masses,
                       'opsim' : opsims})

# %%
eff_df = det_df[det_df['opsim']=='baseline_v3.6_10yrs'].sort_values('pbhmass').reset_index(drop=True)

# %%
eff_df['pbhmass']
# Out:
# 0     1.000000e-12
# 1     3.162278e-12
# 2     1.000000e-11
# 3     3.162278e-11
# 4     1.000000e-10
# 5     3.162278e-10
# 6     1.000000e-09
# 7     3.162278e-09
# 8     1.000000e-08
# 9     3.162278e-08
# 10    1.000000e-07
# 11    3.162278e-07
# 12    1.000000e-06
# 13    3.162278e-06
# 14    1.000000e-05
# 15    3.162278e-05
# 16    1.000000e-04
# 17    3.162278e-04
# 18    1.000000e-03
# 19    3.162278e-03
# 20    1.000000e-02
# 21    3.162278e-02
# 22    1.000000e-01
# 23    3.162278e-01
# 24    1.000000e+00
# 25    3.162278e+00
# 26    1.000000e+01
# 27    3.162278e+01
# 28    1.000000e+02
# 29    3.162278e+02
# 30    1.000000e+03
# 31    3.162278e+03
# 32    1.000000e+04
# 33    3.162278e+04
# 34    1.000000e+05
# 35    3.162278e+05
# 36    1.000000e+06
# Name: pbhmass, dtype: float64

# %%
rates_by_mass.keys()
# Out:
# dict_keys([1e-12, 1.7782794100389228e-12, 3.1622776601683794e-12, 5.6234132519034904e-12, 1e-11, 1.7782794100389227e-11, 3.1622776601683794e-11, 5.6234132519034906e-11, 1e-10, 1.778279410038923e-10, 3.1622776601683795e-10, 5.623413251903491e-10, 1e-09, 1.7782794100389228e-09, 3.1622776601683795e-09, 5.623413251903491e-09, 1e-08, 1.7782794100389228e-08, 3.162277660168379e-08, 5.6234132519034905e-08, 1e-07, 1.7782794100389227e-07, 3.162277660168379e-07, 5.62341325190349e-07, 1e-06, 1.778279410038923e-06, 3.162277660168379e-06, 5.623413251903491e-06, 1e-05, 1.778279410038923e-05, 3.1622776601683795e-05, 5.623413251903491e-05, 0.0001, 0.00017782794100389227, 0.00031622776601683794, 0.0005623413251903491, 0.001, 0.0017782794100389228, 0.0031622776601683794, 0.005623413251903491, 0.01, 0.01778279410038923, 0.03162277660168379, 0.05623413251903491, 0.1, 0.1778279410038923, 0.31622776601683794, 0.5623413251903491, 1.0, 1.7782794100389228, 3.1622776601683795, 5.623413251903491, 10.0, 17.78279410038923, 31.622776601683793, 56.23413251903491, 100.0, 177.82794100389228, 316.22776601683796, 562.341325190349, 1000.0, 1778.2794100389228, 3162.2776601683795, 5623.413251903491, 10000.0, 17782.794100389227, 31622.776601683792, 56234.13251903491, 100000.0, 177827.94100389228, 316227.7660168379, 562341.3251903491, 1000000.0])

# %%
det_counts = {}
for mass, rate in rates_by_mass.items():
  if mass not in eff_df['pbhmass'].unique():
    continue
  try:
    eff  = eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'].iloc[0]
  except:
    print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
  # print(mass)
  print(eff)
  det_counts[mass] = rate * eff
det_counts_df = pd.DataFrame(det_counts.items(), columns=['pbhmass', 'Detected events (baseline)'])
# Out:
# 0.0082
# 0.0082
# 0.0082
# 0.0082
# 0.0082
# 0.0082
# 0.0082
# 0.0082
# 0.0082
# 0.0101
# 0.0099
# 0.0096
# 0.0089
# 0.0109
# 0.012
# 0.0177
# 0.0292
# 0.0462
# 0.0717
# 0.1065
# 0.1278
# 0.1787
# 0.2281
# 0.2752
# 0.3134
# 0.3681
# 0.3969
# 0.4198
# 0.4192
# 0.4025
# 0.3618
# 0.3161
# 0.2762
# 0.2332
# 0.2093
# 0.198
# 0.1956

# %%
exclusions = {}
for mass, rate in rates_by_mass.items():
  if mass not in eff_df['pbhmass'].unique():
    continue
  try:
    eff  = eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'].iloc[0]
  except:
    print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
  # print(mass)
  # print(eff)
  exclusions[mass] = exclusion_from_rate(rate * eff)

# %%
exclusions_min = {}
total_background = 819236
for mass, rate in rates_by_mass.items():
  if mass not in eff_df['pbhmass'].unique():
    continue
  try:
    eff  = eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'].iloc[0]
  except:
    print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
  # print(mass)
  # print(eff)
  background = total_background * log_fraction(crossing_time_bounds[mass])
  exclusions_min[mass] = exclusion_from_rate(rate * eff * .9 + background, background)

# %%
exclusions_min
# Out:
# {1e-12: 1,
#  3.1622776601683794e-12: 1,
#  1e-11: 1,
#  3.1622776601683794e-11: 1,
#  1e-10: 1,
#  3.1622776601683795e-10: 1,
#  1e-09: 1,
#  3.1622776601683795e-09: 1,
#  1e-08: 1,
#  3.162277660168379e-08: 1,
#  1e-07: 1,
#  3.162277660168379e-07: 1,
#  1e-06: 1,
#  3.162277660168379e-06: 1,
#  1e-05: 0.9974218733034753,
#  3.1622776601683795e-05: 0.976316056632742,
#  0.0001: 0.9009564940738327,
#  0.00031622776601683794: 0.7805441739450819,
#  0.001: 0.7269680953896769,
#  0.0031622776601683794: 0.7445728366395233,
#  0.01: 0.5678830967809122,
#  0.03162277660168379: 0.3389400500127353,
#  0.1: 0.29872654842255253,
#  0.31622776601683794: 0.4787684102726839,
#  1.0: 0.667626808902045,
#  3.1622776601683795: 0.6815977291748548,
#  10.0: 0.789887991393986,
#  31.622776601683793: 0.8614922237795921,
#  100.0: 0.9184213179662657,
#  316.22776601683796: 0.9553371479384382,
#  1000.0: 0.9784602072256648,
#  3162.2776601683795: 0.9916500429558509,
#  10000.0: 0.9995009588518807,
#  31622.776601683792: 1,
#  100000.0: 1,
#  316227.7660168379: 1,
#  1000000.0: 1}

# %%
exclusion_df = pd.DataFrame(exclusions.items(), columns=['pbhmass', 'exclusion'])

# %%
exclusion_min_df = pd.DataFrame(exclusions_min.items(), columns=['pbhmass', 'exclusion'])

# %%
exclusion_min_df
# Out:
#          pbhmass  exclusion
# 0   1.000000e-12   1.000000
# 1   3.162278e-12   1.000000
# 2   1.000000e-11   1.000000
# 3   3.162278e-11   1.000000
# 4   1.000000e-10   1.000000
# 5   3.162278e-10   1.000000
# 6   1.000000e-09   1.000000
# 7   3.162278e-09   1.000000
# 8   1.000000e-08   1.000000
# 9   3.162278e-08   1.000000
# 10  1.000000e-07   1.000000
# 11  3.162278e-07   1.000000
# 12  1.000000e-06   1.000000
# 13  3.162278e-06   1.000000
# 14  1.000000e-05   0.997422
# 15  3.162278e-05   0.976316
# 16  1.000000e-04   0.900956
# 17  3.162278e-04   0.780544
# 18  1.000000e-03   0.726968
# 19  3.162278e-03   0.744573
# 20  1.000000e-02   0.567883
# 21  3.162278e-02   0.338940
# 22  1.000000e-01   0.298727
# 23  3.162278e-01   0.478768
# 24  1.000000e+00   0.667627
# 25  3.162278e+00   0.681598
# 26  1.000000e+01   0.789888
# 27  3.162278e+01   0.861492
# 28  1.000000e+02   0.918421
# 29  3.162278e+02   0.955337
# 30  1.000000e+03   0.978460
# 31  3.162278e+03   0.991650
# 32  1.000000e+04   0.999501
# 33  3.162278e+04   1.000000
# 34  1.000000e+05   1.000000
# 35  3.162278e+05   1.000000
# 36  1.000000e+06   1.000000

# %%
sns.lineplot(exclusion_df, x='pbhmass',y='exclusion')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'PBH Mass ($M_\odot$)')
plt.ylabel(r'$f_{DM}$')
plt.title('95% Exclusions on PBH fraction of dark matter for baseline LSST')
# Out:
# Text(0.5, 1.0, '95% Exclusions on PBH fraction of dark matter for baseline LSST')

# %%
exclusion_df.to_csv('LSST-bestcase.txt', sep=' ', index=False)

# %%
sns.lineplot(exclusion_min_df, x='pbhmass',y='exclusion')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'PBH Mass ($M_\odot$)')
plt.ylabel(r'$f_{DM}$')
plt.title('95% Exclusions on PBH fraction of dark matter for baseline LSST\n'
          'with worst-case backgrounds')
plt.tight_layout()
plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/rubinsim/exclusions-worst-case-te-0.9-temp.pdf')

# %%
sns.lineplot(det_counts_df, x='pbhmass',y='Detected events (baseline)',linestyle='None',marker='.')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'PBH Mass ($M_\odot$)')
plt.ylabel(r'Number of events')
plt.title('Number of in-principle detectible microlensing events for baseline LSST')
plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/rubinsim/n-events-by-pbhmass.pdf')

# %%
def bhmf(m: float, mc=6.3, ms=1.6):
  """Milky way black hole mass density function, as an exponential with cutofff
      defaults to fig 2 of https://arxiv.org/pdf/1006.2834
  Args:
      m (float): Mass in question (SM)
      mc (float): Cutoff mass (SM)
      ms (float): Mass scale (SM)
  """

  return (np.exp((mc-m)/ms)/ms)*(m>mc)

# %%
xs = np.linspace(1,25,50)
# ys = np.logspace(-2,0)
ys = bhmf(xs)
plt.plot(xs,ys)
plt.xlabel(r'BH Mass ($M_\odot$)')
plt.ylabel('Probability density')
plt.title('Exponential mass distribution of Stellar Origin Black Holes in the Milky Way')
plt.yscale('log')

# %%
scipy.integrate.quad(bhmf,6.3,100)
# Out:
# (0.9999999999999994, 2.1789394282476816e-10)

# %%
def get_sobh_counts(m, width=2.):
  return scipy.integrate.quad(bhmf,m/width,m*width)
def get_bucketed_bhs(masses, width=2.):
  """Evaluate number of background indistinguishable SOBHs 
     at some masses, by integrating the mass density function
     around a factor of width to either side of each mass

  Args:
      masses (iterable): List of masses (SM)
      width (float, optional): Factor away from each mass to integrate. Defaults to 2.
  """
  counts = {}
  for m in masses:
    counts[m] = scipy.integrate.quad(bhmf,m/width,m*width)
  return counts

# %%
n_bh = 100*10**6
tot_dm = 1.37*10**11 # total DM mass in MW, according to https://doi.org/10.1051/0004-6361/201833355
exclusions_sobh = {}
for mass, rate in rates_by_mass.items():
  n_bh_mass = ( n_bh / (tot_dm / mass ) ) * get_sobh_counts(mass)[0]
  # print(n_bh_mass)
  if mass not in eff_df['pbhmass'].unique():
    continue
  try:
    eff  = eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'].iloc[0]
  except:
    pass
    # print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
  # print(mass)
  # print(eff)
  exclusions_sobh[mass] = exclusion_from_rate(rate * eff * (1 + n_bh_mass), rate * eff * n_bh_mass)

# %%
n_bh = 100*10**6
tot_dm = 1.37*10**11 # total DM mass in MW, according to https://doi.org/10.1051/0004-6361/201833355
exclusions_sobh = {}
for mass, rate in rates_by_mass.items():
  n_bh_mass = ( n_bh / (tot_dm / mass ) ) * get_sobh_counts(mass)[0]
  # print(n_bh_mass)
  if mass not in eff_df['pbhmass'].unique():
    continue
  try:
    eff  = eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'].iloc[0]
  except:
    pass
    # print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
  # print(mass)
  # print(eff)
  exclusions_sobh[mass] = exclusion_from_rate(rate * eff * (1 + n_bh_mass), rate * eff * n_bh_mass)

# %%
eff_df
# Out:
#        eff       pbhmass                opsim
# 0   0.0082  1.000000e-12  baseline_v3.6_10yrs
# 1   0.0082  3.162278e-12  baseline_v3.6_10yrs
# 2   0.0083  1.000000e-11  baseline_v3.6_10yrs
# 3   0.0089  3.162278e-11  baseline_v3.6_10yrs
# 4   0.0087  1.000000e-10  baseline_v3.6_10yrs
# 5   0.0086  3.162278e-10  baseline_v3.6_10yrs
# 6   0.0078  1.000000e-09  baseline_v3.6_10yrs
# 7   0.0096  3.162278e-09  baseline_v3.6_10yrs
# 8   0.0065  1.000000e-08  baseline_v3.6_10yrs
# 9   0.0101  3.162278e-08  baseline_v3.6_10yrs
# 10  0.0099  1.000000e-07  baseline_v3.6_10yrs
# 11  0.0096  3.162278e-07  baseline_v3.6_10yrs
# 12  0.0089  1.000000e-06  baseline_v3.6_10yrs
# 13  0.0109  3.162278e-06  baseline_v3.6_10yrs
# 14  0.0120  1.000000e-05  baseline_v3.6_10yrs
# 15  0.0177  3.162278e-05  baseline_v3.6_10yrs
# 16  0.0292  1.000000e-04  baseline_v3.6_10yrs
# 17  0.0462  3.162278e-04  baseline_v3.6_10yrs
# 18  0.0717  1.000000e-03  baseline_v3.6_10yrs
# 19  0.1065  3.162278e-03  baseline_v3.6_10yrs
# 20  0.1278  1.000000e-02  baseline_v3.6_10yrs
# 21  0.1787  3.162278e-02  baseline_v3.6_10yrs
# 22  0.2281  1.000000e-01  baseline_v3.6_10yrs
# 23  0.2752  3.162278e-01  baseline_v3.6_10yrs
# 24  0.3134  1.000000e+00  baseline_v3.6_10yrs
# 25  0.3681  3.162278e+00  baseline_v3.6_10yrs
# 26  0.3969  1.000000e+01  baseline_v3.6_10yrs
# 27  0.4198  3.162278e+01  baseline_v3.6_10yrs
# 28  0.4192  1.000000e+02  baseline_v3.6_10yrs
# 29  0.4025  3.162278e+02  baseline_v3.6_10yrs
# 30  0.3618  1.000000e+03  baseline_v3.6_10yrs
# 31  0.3161  3.162278e+03  baseline_v3.6_10yrs
# 32  0.2762  1.000000e+04  baseline_v3.6_10yrs
# 33  0.2332  3.162278e+04  baseline_v3.6_10yrs
# 34  0.2093  1.000000e+05  baseline_v3.6_10yrs
# 35  0.1980  3.162278e+05  baseline_v3.6_10yrs
# 36  0.1956  1.000000e+06  baseline_v3.6_10yrs

# %%
pbhmass = 10
npbh = tot_dm/pbhmass

print(pbhmass)
print(rates_by_mass[pbhmass]*n_bh/npbh)

print(eff_df[eff_df['pbhmass']==pbhmass]['eff'].iloc[0]*rates_by_mass[pbhmass]*n_bh/npbh)
# Out:
# 10
# 1025.963503649635
# 407.2049145985401

# %%
eff_df[np.isclose(eff_df['pbhmass'],pbhmass)]['eff']
# Out:
# Series([], Name: eff, dtype: float64)

# %%
eff_df['pbhmass']
# Out:
# 0     1.000000e-12
# 1     3.162278e-12
# 2     1.000000e-11
# 3     3.162278e-11
# 4     1.000000e-10
# 5     3.162278e-10
# 6     1.000000e-09
# 7     3.162278e-09
# 8     1.000000e-08
# 9     3.162278e-08
# 10    1.000000e-07
# 11    3.162278e-07
# 12    1.000000e-06
# 13    3.162278e-06
# 14    1.000000e-05
# 15    3.162278e-05
# 16    1.000000e-04
# 17    3.162278e-04
# 18    1.000000e-03
# 19    3.162278e-03
# 20    1.000000e-02
# 21    3.162278e-02
# 22    1.000000e-01
# 23    3.162278e-01
# 24    1.000000e+00
# 25    3.162278e+00
# 26    1.000000e+01
# 27    3.162278e+01
# 28    1.000000e+02
# 29    3.162278e+02
# 30    1.000000e+03
# 31    3.162278e+03
# 32    1.000000e+04
# 33    3.162278e+04
# 34    1.000000e+05
# 35    3.162278e+05
# 36    1.000000e+06
# Name: pbhmass, dtype: float64

# %%
exclusion_sobh_df = pd.DataFrame(exclusions_sobh.items(), columns=['pbhmass', 'exclusion'])

# %%
sns.lineplot(exclusion_sobh_df, x='pbhmass',y='exclusion')
plt.xscale('log')
plt.yscale('log')
plt.xlabel(r'PBH Mass ($M_\odot$)')
plt.ylabel(r'$f_{DM}$')
plt.title('95% Exclusions on PBH fraction of dark matter for baseline LSST\n'
          'with stellar origin BH backgrounds')
# Out:
# Text(0.5, 1.0, '95% Exclusions on PBH fraction of dark matter for baseline LSST\nwith stellar origin BH backgrounds')

# %%
exclusion_sobh_df.to_csv('LSST-bestcase-sobh.txt', sep=' ', index=False, header=False)

# %%
real_det_eff=0.5
n_bh = 100*10**6
tot_dm = 1.37*10**11 # total DM mass in MW, according to https://doi.org/10.1051/0004-6361/201833355
exclusions_sobh_in_time = []
for mass, rate in rates_by_mass.items():
  n_bh_mass = ( n_bh / (tot_dm / mass ) ) * get_sobh_counts(mass)[0]
  # print(n_bh_mass)
  if mass not in eff_df['pbhmass'].unique():
    continue
  try:
    eff  = eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'].iloc[0]
  except:
    pass
    # print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
  # print(mass)
  # print(eff)
  # for t in np.arange(1./12,10.,1./12):

  for t in np.logspace(-4,1,100):
    exclusions_sobh_in_time.append([
      mass,
      t*12,
      exclusion_from_rate(real_det_eff*rate * eff * (1 + n_bh_mass)*t/10, real_det_eff*rate * eff * n_bh_mass*t/10)
    ])

# %%
exclusions_sobh_in_time_df = pd.DataFrame(exclusions_sobh_in_time,columns=['pbhmass','time (months)', 'exclusion'])

# %%
exclusions_sobh_in_time_df
# Out:
#            pbhmass  time (months)  exclusion
# 0     1.000000e-12       0.001200        1.0
# 1     1.000000e-12       0.001348        1.0
# 2     1.000000e-12       0.001514        1.0
# 3     1.000000e-12       0.001701        1.0
# 4     1.000000e-12       0.001911        1.0
# ...            ...            ...        ...
# 3695  1.000000e+06      75.363497        1.0
# 3696  1.000000e+06      84.657628        1.0
# 3697  1.000000e+06      95.097948        1.0
# 3698  1.000000e+06     106.825810        1.0
# 3699  1.000000e+06     120.000000        1.0
#
# [3700 rows x 3 columns]

# %%
df_pivot = np.log10(exclusions_sobh_in_time_df.pivot(index="time (months)", columns="pbhmass", values="exclusion"))
sns.heatmap(df_pivot, fmt='.1e',cbar_kws={'label': r'log$_{10}(f_{DM})$'})
# # Format x-axis labels (columns)
# plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:.1e}'))

# # Format y-axis labels (index)
# plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y:.1f}'))

# plt.yscale('log')

# Control y-axis ticks to show integer indices
ax = plt.gca()
y_tick_locs = np.arange(0, len(df_pivot.index), 4)  # Example: every 2nd tick
y_tick_labels = [f'{df_pivot.index[int(i)]:.1e}' for i in y_tick_locs]  # Simplified labels

ax.set_yticks(y_tick_locs)
ax.set_yticklabels(y_tick_labels)

# Control x-axis (if needed)
x_tick_locs = np.arange(0, len(df_pivot.columns), 3)  # Example: every 3rd tick
x_tick_labels = [f'{df_pivot.columns[int(i)]:.1e}' for i in x_tick_locs]  # Scientific notation

ax.set_xticks(x_tick_locs)
ax.set_xticklabels(x_tick_labels, rotation=45)

ax.set_title('Exclusions over time for LSST')
plt.tight_layout()
plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/exclusions/exclusions-over-time-simple.pdf')

# %%
df_pivot.pivot?
# Out:
# Signature: df_pivot.pivot(*, columns, index=<no_default>, values=<no_default>) -> 'DataFrame'
# Docstring:
# Return reshaped DataFrame organized by given index / column values.
#
# Reshape data (produce a "pivot" table) based on column values. Uses
# unique values from specified `index` / `columns` to form axes of the
# resulting DataFrame. This function does not support data
# aggregation, multiple values will result in a MultiIndex in the
# columns. See the :ref:`User Guide <reshaping>` for more on reshaping.
#
# Parameters
# ----------
# columns : str or object or a list of str
#     Column to use to make new frame's columns.
# index : str or object or a list of str, optional
#     Column to use to make new frame's index. If not given, uses existing index.
# values : str, object or a list of the previous, optional
#     Column(s) to use for populating new frame's values. If not
#     specified, all remaining columns will be used and the result will
#     have hierarchically indexed columns.
#
# Returns
# -------
# DataFrame
#     Returns reshaped DataFrame.
#
# Raises
# ------
# ValueError:
#     When there are any `index`, `columns` combinations with multiple
#     values. `DataFrame.pivot_table` when you need to aggregate.
#
# See Also
# --------
# DataFrame.pivot_table : Generalization of pivot that can handle
#     duplicate values for one index/column pair.
# DataFrame.unstack : Pivot based on the index values instead of a
#     column.
# wide_to_long : Wide panel to long format. Less flexible but more
#     user-friendly than melt.
#
# Notes
# -----
# For finer-tuned control, see hierarchical indexing documentation along
# with the related stack/unstack methods.
#
# Reference :ref:`the user guide <reshaping.pivot>` for more examples.
#
# Examples
# --------
# >>> df = pd.DataFrame({'foo': ['one', 'one', 'one', 'two', 'two',
# ...                            'two'],
# ...                    'bar': ['A', 'B', 'C', 'A', 'B', 'C'],
# ...                    'baz': [1, 2, 3, 4, 5, 6],
# ...                    'zoo': ['x', 'y', 'z', 'q', 'w', 't']})
# >>> df
#     foo   bar  baz  zoo
# 0   one   A    1    x
# 1   one   B    2    y
# 2   one   C    3    z
# 3   two   A    4    q
# 4   two   B    5    w
# 5   two   C    6    t
#
# >>> df.pivot(index='foo', columns='bar', values='baz')
# bar  A   B   C
# foo
# one  1   2   3
# two  4   5   6
#
# >>> df.pivot(index='foo', columns='bar')['baz']
# bar  A   B   C
# foo
# one  1   2   3
# two  4   5   6
#
# >>> df.pivot(index='foo', columns='bar', values=['baz', 'zoo'])
#       baz       zoo
# bar   A  B  C   A  B  C
# foo
# one   1  2  3   x  y  z
# two   4  5  6   q  w  t
#
# You could also assign a list of column names or a list of index names.
#
# >>> df = pd.DataFrame({
# ...        "lev1": [1, 1, 1, 2, 2, 2],
# ...        "lev2": [1, 1, 2, 1, 1, 2],
# ...        "lev3": [1, 2, 1, 2, 1, 2],
# ...        "lev4": [1, 2, 3, 4, 5, 6],
# ...        "values": [0, 1, 2, 3, 4, 5]})
# >>> df
#     lev1 lev2 lev3 lev4 values
# 0   1    1    1    1    0
# 1   1    1    2    2    1
# 2   1    2    1    3    2
# 3   2    1    2    4    3
# 4   2    1    1    5    4
# 5   2    2    2    6    5
#
# >>> df.pivot(index="lev1", columns=["lev2", "lev3"], values="values")
# lev2    1         2
# lev3    1    2    1    2
# lev1
# 1     0.0  1.0  2.0  NaN
# 2     4.0  3.0  NaN  5.0
#
# >>> df.pivot(index=["lev1", "lev2"], columns=["lev3"], values="values")
#       lev3    1    2
# lev1  lev2
#    1     1  0.0  1.0
#          2  2.0  NaN
#    2     1  4.0  3.0
#          2  NaN  5.0
#
# A ValueError is raised if there are any duplicates.
#
# >>> df = pd.DataFrame({"foo": ['one', 'one', 'two', 'two'],
# ...                    "bar": ['A', 'A', 'B', 'C'],
# ...                    "baz": [1, 2, 3, 4]})
# >>> df
#    foo bar  baz
# 0  one   A    1
# 1  one   A    2
# 2  two   B    3
# 3  two   C    4
#
# Notice that the first two rows are the same for our `index`
# and `columns` arguments.
#
# >>> df.pivot(index='foo', columns='bar', values='baz')
# Traceback (most recent call last):
#    ...
# ValueError: Index contains duplicate entries, cannot reshape
# File:      ~/mambaforge/envs/rubinsim/lib/python3.11/site-packages/pandas/core/frame.py
# Type:      method

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k-partials/detections/*.pickle')
print(result_files_wide10k)
time_mass_eff=[]
for file in result_files_wide10k:
  with open(file,'rb') as f:
    info,results = pickle.load(f)
    elapsed = float(info['constraint'].split('<')[-1])
    eff = np.sum(results)/results.shape[0]
    mass = info['pbhmass']
    time_mass_eff.append((elapsed, mass, eff))
# Out:
# ['/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<3653.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+00sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<3653.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+01sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+02sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+02sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+02sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+02sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detections/baseline_v3.6_10yrs_1.0000e+02sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/detection ...

# %%
time_eff_df = pd.DataFrame(time_mass_eff, columns=['time', 'pbhmass', 'eff' ])

# %%
time_eff_df
# Out:
#        time       pbhmass     eff
# 0    1156.0  1.000000e+00  0.1007
# 1     116.0  1.000000e+00  0.0071
# 2      12.0  1.000000e+00  0.0002
# 3    2054.0  1.000000e+00  0.1755
# 4     206.0  1.000000e+00  0.0128
# ..      ...           ...     ...
# 476    37.0  3.162278e-12  0.0000
# 477     4.0  3.162278e-12  0.0000
# 478    65.0  3.162278e-12  0.0000
# 479   650.0  3.162278e-12  0.0011
# 480     7.0  3.162278e-12  0.0000
#
# [481 rows x 3 columns]

# %%
real_det_eff=.5
n_bh = 100*10**6
tot_dm = 1.37*10**11 # total DM mass in MW, according to https://doi.org/10.1051/0004-6361/201833355
exclusions_sobh_in_time = []
for mass, rate in rates_by_mass.items():

  for t in sorted(time_eff_df['time'].unique()):
    n_bh_mass = ( n_bh / (tot_dm / mass ) ) * get_sobh_counts(mass)[0]
    # print(n_bh_mass)
    if mass not in time_eff_df['pbhmass'].unique():
      continue
    try:
      eff  = time_eff_df[(np.isclose(time_eff_df['pbhmass'],mass) )
                         & (t==time_eff_df['time'])]['eff'].iloc[0]
    except:
      pass
      # print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
    # print(mass)
    # print(eff)
    # for t in np.arange(1./12,10.,1./12):

    exclusions_sobh_in_time.append([
      mass,
      t,
      exclusion_from_rate(real_det_eff*rate * eff * (1 + n_bh_mass), real_det_eff*rate * eff * n_bh_mass)
    ])

# %%
time_eff_df[(np.isclose(time_eff_df['pbhmass'],mass) )
                         & (t==time_eff_df['time'])]['eff'].iloc[0]
# Out:
# 0.1956

# %%
exclusions_sobh_in_time
# Out:
# [[1e-12, 4.0, 1],
#  [1e-12, 7.0, 1],
#  [1e-12, 12.0, 1],
#  [1e-12, 21.0, 1],
#  [1e-12, 37.0, 1],
#  [1e-12, 65.0, 1],
#  [1e-12, 116.0, 1],
#  [1e-12, 206.0, 1],
#  [1e-12, 366.0, 1],
#  [1e-12, 650.0, 1],
#  [1e-12, 1156.0, 1],
#  [316227.7660168379, 65.0, 1],
#  [316227.7660168379, 116.0, 1],
#  [316227.7660168379, 206.0, 1],
#  [316227.7660168379, 366.0, 1],
#  [316227.7660168379, 650.0, 1],
#  [316227.7660168379, 1156.0, 1],
#  [316227.7660168379, 2054.0, 1],
#  [316227.7660168379, 3653.0, 1],
#  [1000000.0, 4.0, 1],
#  [1000000.0, 7.0, 1],
#  [1000000.0, 12.0, 1],
#  [1000000.0, 21.0, 1],
#  [1000000.0, 37.0, 1],
#  [1000000.0, 65.0, 1],
#  [1000000.0, 116.0, 1],
#  [1000000.0, 206.0, 1],
#  [1000000.0, 366.0, 1],
#  [1000000.0, 650.0, 1],
#  [1000000.0, 1156.0, 1],
#  [1000000.0, 2054.0, 1],
#  [1000000.0, 3653.0, 1]]

# %%
eff
# Out:
# 0.1956

# %%
exclusions_sobh_in_time_df = pd.DataFrame(exclusions_sobh_in_time,columns=['pbhmass','time (days)', 'exclusion'])

# %%
exclusions_sobh_in_time_df['exclusion'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_pivot = np.log10(exclusions_sobh_in_time_df.pivot(index="time (days)", columns="pbhmass", values="exclusion"))
sns.heatmap(df_pivot, fmt='.1e',cbar_kws={'label': r'log$_{10}(f_{DM})$'})
# # Format x-axis labels (columns)
# plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:.1e}'))

# # Format y-axis labels (index)
# plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y:.1f}'))

# plt.yscale('log')

# Control y-axis ticks to show integer indices
ax = plt.gca()
y_tick_locs = np.arange(0, len(df_pivot.index), 4)  # Example: every 2nd tick
y_tick_labels = [f'{df_pivot.index[int(i)]:.1e}' for i in y_tick_locs]  # Simplified labels

ax.set_yticks(y_tick_locs)
ax.set_yticklabels(y_tick_labels)

# Control x-axis (if needed)
x_tick_locs = np.arange(0, len(df_pivot.columns), 3)  # Example: every 3rd tick
x_tick_labels = [f'{df_pivot.columns[int(i)]:.1e}' for i in x_tick_locs]  # Scientific notation

ax.set_xticks(x_tick_locs)
ax.set_xticklabels(x_tick_labels, rotation=45)

ax.set_title('Exclusions over time for LSST')
plt.tight_layout()
# plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/exclusions/exclusions-over-time-simple.pdf')

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k-partials/Fisher/*.pickle')
print(result_files_wide10k)
time_mass_eff_fisher=[]
results_fisher=[]
for file in result_files_wide10k:
  with open(file,'rb') as f:
    info,results = pickle.load(f)
    results_fisher.append((info, results))
    elapsed = float(info['constraint'].split('<')[-1])
    eff = np.sum(results<.05)/results.shape[0]
    mass = info['pbhmass']
    time_mass_eff_fisher.append((elapsed, mass, eff))
time_eff_df_fisher = pd.DataFrame(time_mass_eff_fisher, columns=['time', 'pbhmass', 'eff' ])
# Out:
# ['/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<3653.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<3653.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/base ...

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k-partials/Fisher/*.pickle')
print(result_files_wide10k)
time_mass_eff_fisher=[]
results_fisher=[]
for file in result_files_wide10k:
  with open(file,'rb') as f:
    info,results = pickle.load(f)
    results_fisher.append((info, results))
    elapsed = float(info['constraint'].split('<')[-1])
    eff = np.sum(results<.05)/results.shape[0]
    mass = info['pbhmass']
    time_mass_eff_fisher.append((elapsed, mass, eff))
time_eff_df_fisher = pd.DataFrame(time_mass_eff_fisher, columns=['time', 'pbhmass', 'eff' ])
# Out:
# ['/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+00sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+01sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+02sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+03sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs_1.0000e+03sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher/baseline_v3.6_10yrs ...

# %%
real_det_eff=1
n_bh = 100*10**6
tot_dm = 1.37*10**11 # total DM mass in MW, according to https://doi.org/10.1051/0004-6361/201833355
exclusions_sobh_in_time_fisher = []
for mass, rate in rates_by_mass.items():

  for t in sorted(time_eff_df_fisher['time'].unique()):
    n_bh_mass = ( n_bh / (tot_dm / mass ) ) * get_sobh_counts(mass)[0]
    # print(n_bh_mass)
    if mass not in time_eff_df_fisher['pbhmass'].unique():
      continue
    try:
      eff  = time_eff_df_fisher[(np.isclose(time_eff_df_fisher['pbhmass'],mass) )
                         & (t==time_eff_df_fisher['time'])]['eff'].iloc[0]
    except:
      pass
      # print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
    # print(mass)
    # print(eff)
    # for t in np.arange(1./12,10.,1./12):

    exclusions_sobh_in_time_fisher.append([
      mass,
      t,
      exclusion_from_rate(real_det_eff*rate * eff * (1 + n_bh_mass) * t/3652, real_det_eff*rate * eff * n_bh_mass * t/3652)
    ])

# %%
exclusions_sobh_in_time_df_fisher = pd.DataFrame(exclusions_sobh_in_time_fisher,columns=['pbhmass','time (days)', 'exclusion'])

# %%
df_pivot = np.log10(exclusions_sobh_in_time_df_fisher.pivot(index="time (days)", columns="pbhmass", values="exclusion"))
sns.heatmap(df_pivot, fmt='.1e',cbar_kws={'label': r'log$_{10}(f_{DM})$'})
# # Format x-axis labels (columns)
# plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:.1e}'))

# # Format y-axis labels (index)
# plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y:.1f}'))

# plt.yscale('log')

# Control y-axis ticks to show integer indices
ax = plt.gca()
y_tick_locs = np.arange(0, len(df_pivot.index), 4)  # Example: every 2nd tick
y_tick_labels = [f'{df_pivot.index[int(i)]:.1e}' for i in y_tick_locs]  # Simplified labels

ax.set_yticks(y_tick_locs)
ax.set_yticklabels(y_tick_labels)

# Control x-axis (if needed)
x_tick_locs = np.arange(0, len(df_pivot.columns), 3)  # Example: every 3rd tick
x_tick_labels = [f'{df_pivot.columns[int(i)]:.1e}' for i in x_tick_locs]  # Scientific notation

ax.set_xticks(x_tick_locs)
ax.set_xticklabels(x_tick_labels, rotation=45)

ax.set_title('Exclusions over time for LSST')
plt.tight_layout()
# plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/exclusions/exclusions-over-time-simple.pdf')

# %%
time_eff_df_fisher[time_eff_df_fisher['time']==7]
# Out:
#          time   pbhmass       eff
# 5   7.000e+00 1.000e+00 7.000e-04
# 11  7.000e+00 1.000e+01 7.000e-04
# 17  7.000e+00 1.000e+02 6.000e-04
# 23  7.000e+00 1.000e+03 0.000e+00
# 29  7.000e+00 1.000e+04 3.000e-04
# 35  7.000e+00 1.000e+05 0.000e+00
# 41  7.000e+00 1.000e+06 1.000e-04
# 47  7.000e+00 1.000e-01 5.000e-04
# 53  7.000e+00 1.000e-02 6.000e-04
# 59  7.000e+00 1.000e-03 1.000e-04
# 65  7.000e+00 1.000e-04 0.000e+00
# 71  7.000e+00 1.000e-05 0.000e+00
# 77  7.000e+00 3.162e+00 9.000e-04
# 83  7.000e+00 3.162e+01 7.000e-04
# 89  7.000e+00 3.162e+02 2.000e-04
# 95  7.000e+00 3.162e+03 4.000e-04
# 101 7.000e+00 3.162e+04 1.000e-04
# 107 7.000e+00 3.162e+05 1.000e-04
# 113 7.000e+00 3.162e-01 7.000e-04
# 119 7.000e+00 3.162e-02 1.000e-03
# 125 7.000e+00 3.162e-03 3.000e-04
# 131 7.000e+00 3.162e-04 1.000e-04
# 137 7.000e+00 3.162e-05 0.000e+00
# 143 7.000e+00 3.162e-06 0.000e+00

# %%
pd.options.display.float_format = '{:.3e}'.format

# %%
result_files_wide10k = glob.glob('/Volumes/thesis/rubin-sim/userdata/'
                         'opsim_ml/wide10k-partials/Fisher_Npts_Nights/*.pickle')
print(result_files_wide10k)
time_mass_eff_fisher=[]
results_fisher=[]
for file in result_files_wide10k:
  with open(file,'rb') as f:
    info,result_fisher, result_n, result_nights = pickle.load(f)
    results_fisher.append((info, result_fisher))
    elapsed = float(info['constraint'].split('<')[-1])
    eff = np.sum((result_fisher<.05)&(result_n>=10)&(result_nights>=10))/result_fisher.shape[0]
    mass = info['pbhmass']
    time_mass_eff_fisher.append((elapsed, mass, eff))
time_eff_df_fisher = pd.DataFrame(time_mass_eff_fisher, columns=['time', 'pbhmass', 'eff' ])
# Out:
# ['/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<3653.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+00sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<2054.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<206.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<21.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<3653.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<366.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<37.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<4.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<65.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<650.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+01sm_night<7.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+02sm_night<1156.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+02sm_night<116.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6_10yrs_1.0000e+02sm_night<12.0.pickle', '/Volumes/thesis/rubin-sim/userdata/opsim_ml/wide10k-partials/Fisher_Npts_Nights/baseline_v3.6 ...

# %%
real_det_eff=1
n_bh = 100*10**6
tot_dm = 1.37*10**11 # total DM mass in MW, according to https://doi.org/10.1051/0004-6361/201833355
exclusions_sobh_in_time_fisher = []
for mass, rate in rates_by_mass.items():

  for t in sorted(time_eff_df_fisher['time'].unique()):
    n_bh_mass = ( n_bh / (tot_dm / mass ) ) * get_sobh_counts(mass)[0]
    # print(n_bh_mass)
    if mass not in time_eff_df_fisher['pbhmass'].unique():
      continue
    try:
      eff  = time_eff_df_fisher[(np.isclose(time_eff_df_fisher['pbhmass'],mass) )
                         & (t==time_eff_df_fisher['time'])]['eff'].iloc[0]
    except:
      pass
      # print(eff_df[np.isclose(eff_df['pbhmass'],mass)]['eff'])
    # print(mass)
    # print(eff)
    # for t in np.arange(1./12,10.,1./12):
    ndetections = real_det_eff*rate * eff * (1 + n_bh_mass) * t/3652

    exclusions_sobh_in_time_fisher.append([
      mass,
      t,
      eff,
      ndetections,
      exclusion_from_rate(ndetections, real_det_eff*rate * eff * n_bh_mass * t/3652)
    ])

# %%
exclusions_sobh_in_time_df_fisher = pd.DataFrame(exclusions_sobh_in_time_fisher,columns=['pbhmass','time (days)', 'eff','ndetections', 'exclusion'])
df_pivot = np.log10(exclusions_sobh_in_time_df_fisher.pivot(index="time (days)", columns="pbhmass", values="exclusion"))
sns.heatmap(df_pivot, fmt='.1e',cbar_kws={'label': r'log$_{10}(f_{DM})$'})
# # Format x-axis labels (columns)
# plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x, _: f'{x:.1e}'))

# # Format y-axis labels (index)
# plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y:.1f}'))

# plt.yscale('log')

# Control y-axis ticks to show integer indices
ax = plt.gca()
y_tick_locs = np.arange(0, len(df_pivot.index), 4)  # Example: every 2nd tick
y_tick_labels = [f'{df_pivot.index[int(i)]:.1e}' for i in y_tick_locs]  # Simplified labels

ax.set_yticks(y_tick_locs)
ax.set_yticklabels(y_tick_labels)

# Control x-axis (if needed)
x_tick_locs = np.arange(0, len(df_pivot.columns), 3)  # Example: every 3rd tick
x_tick_labels = [f'{df_pivot.columns[int(i)]:.1e}' for i in x_tick_locs]  # Scientific notation

ax.set_xticks(x_tick_locs)
ax.set_xticklabels(x_tick_labels, rotation=45)

ax.set_title('Exclusions over time for LSST')
plt.tight_layout()
# plt.savefig('/Users/duncan/Documents/code/physics/dissertation/ims/exclusions/exclusions-over-time-fisher-npts-nights-10k.pdf')

# %%
exclusions_sobh_in_time_df_fisher[np.isclose(exclusions_sobh_in_time_df_fisher['pbhmass'],1*10**(-4))]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 exclusions_sobh_in_time_df_fisher[np.isclose(exclusions_sobh_in_time_df_fisher['pbhmass'],1*10**(-4))]
#
# NameError: name 'exclusions_sobh_in_time_df_fisher' is not defined

# %%
rates_by_mass[1*10**(-4)]
# Out:
# 910358

# %%
exclusions_sobh_in_time_df_fisher
# Out:
# Empty DataFrame
# Columns: [pbhmass, time (days), eff, ndetections, exclusion]
# Index: []

# %%
df_pivot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 df_pivot
#
# NameError: name 'df_pivot' is not defined
