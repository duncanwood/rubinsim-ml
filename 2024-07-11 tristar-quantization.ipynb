# %%
import dl
from getpass import getpass
# import LensCalcPy.eventsampling as es
# from LensCalcPy.galaxy import MilkyWayModel

# from rubin_scheduler.utils import equatorial_from_galactic, \
#                             hpid2_ra_dec, ra_dec2_hpid
# import rubin_scheduler.maf as maf

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import dl
from dl import queryClient as qc
from dl import authClient as ac
from getpass import getpass

# %%
ac.whoAmI()
# Out:
# 'duncanwood'

# %%
# ac.login(input("Enter user name: (+ENTER) "),getpass("Enter password: (+ENTER) ")) # credentials to log into datalab
query = 'SELECT mu0 FROM lsst_sim.simdr2 WHERE mu0 BETWEEN 17.72 AND 18.01 ORDER BY random_id LIMIT 10000' # SQL query string
result = qc.query(sql=query) # your query result as a CSV-formatted string
df = qc.convert(result) # result as a Pandas data frame
del result

# %%
df.hist(bins=200)
# Out:
# array([[<Axes: title={'center': 'mu0'}>]], dtype=object)

# %%
df['mu0'].unique()
# Out:
# array([18.  , 17.95, 17.8 , 17.85, 17.75, 17.9 ])

# %%
df
# Out:
#           mu0
# 0       17.75
# 1       17.75
# 2       17.75
# 3       17.75
# 4       17.75
# ...       ...
# 999995  17.75
# 999996  17.75
# 999997  17.75
# 999998  17.75
# 999999  17.75
#
# [1000000 rows x 1 columns]
